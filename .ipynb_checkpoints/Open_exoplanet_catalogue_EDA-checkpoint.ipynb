# %% [markdown]
# # Open Exoplanet Catalogue

# %% [markdown]
# Doing some preliminary data exploration on the Open Exoplanet Catalogue.

# %%
# First we import some useful packages.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Loading the data.
exoplanets = pd.read_csv('oec.csv')

# %% [markdown]
# Let's see what the data looks like.

# %%
exoplanets
# Out:
#      PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt   PeriodDays  \
# 0         HD 143761 b         0            1.0450        NaN    39.845800
# 1         HD 143761 c         0            0.0790        NaN   102.540000
# 2         KOI-1843.03         0            0.0014    0.05400     0.176891
# 3         KOI-1843.01         0               NaN    0.11400     4.194525
# 4         KOI-1843.02         0               NaN    0.07100     6.356006
# 5          Kepler-9 b         0            0.2500    0.84000    19.224180
# 6          Kepler-9 c         0            0.1700    0.82000    39.031060
# 7          Kepler-9 d         0            0.0220    0.14700     1.592851
# 8          GJ 160.2 b         0            0.0321        NaN     5.235400
# 9        Kepler-566 b         0               NaN    0.19200    18.427946
# 10         WASP-124 b         0            0.6000    1.24000     3.372650
# 11        HD 240210 b         0            5.2100        NaN   501.750000
# ...

# %% [markdown]
# The original csv is comma separated but Pandas (and Jupyter) displays in a pretty tabular form. The index on the left is added by Panda.
#
# So we have 3584 rows x 25 rows, which corresponds to our 3584 exoplanets.
#
# Pandas provide an eay way to get the name of the columns.

# %%
exoplanets.columns
# Out:
# Index(['PlanetIdentifier', 'TypeFlag', 'PlanetaryMassJpt', 'RadiusJpt',
#        'PeriodDays', 'SemiMajorAxisAU', 'Eccentricity', 'PeriastronDeg',
#        'LongitudeDeg', 'AscendingNodeDeg', 'InclinationDeg', 'SurfaceTempK',
#        'AgeGyr', 'DiscoveryMethod', 'DiscoveryYear', 'LastUpdated',
#        'RightAscension', 'Declination', 'DistFromSunParsec',
#        'HostStarMassSlrMass', 'HostStarRadiusSlrRad', 'HostStarMetallicity',
#        'HostStarTempK', 'HostStarAgeGyr', 'ListsPlanetIsOn'],
#       dtype='object')

# %% [markdown]
# An another useful command is the .info() function.

# %%
exoplanets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3584 entries, 0 to 3583
# Data columns (total 25 columns):
# PlanetIdentifier        3584 non-null object
# TypeFlag                3584 non-null int64
# PlanetaryMassJpt        1313 non-null float64
# RadiusJpt               2774 non-null float64
# PeriodDays              3485 non-null float64
# SemiMajorAxisAU         1406 non-null float64
# Eccentricity            1108 non-null float64
# PeriastronDeg           328 non-null float64
# LongitudeDeg            43 non-null float64
# AscendingNodeDeg        46 non-null float64
# InclinationDeg          665 non-null float64
# SurfaceTempK            741 non-null float64
# AgeGyr                  2 non-null float64
# DiscoveryMethod         3521 non-null object
# DiscoveryYear           3574 non-null float64
# LastUpdated             3576 non-null object
# RightAscension          3574 non-null object
# Declination             3574 non-null object
# ...

# %%
As you can see, it gives you a summary of your dataset.

# %%
exoplanets.describe()
# Out:
#           TypeFlag  PlanetaryMassJpt    RadiusJpt     PeriodDays  \
# count  3584.000000       1313.000000  2774.000000    3485.000000
# mean      0.097656          2.890944     0.371190     537.248317
# std       0.424554         10.204485     0.416871    7509.660676
# min       0.000000          0.000008     0.002300       0.090706
# 25%       0.000000          0.150000     0.141062       4.757940
# 50%       0.000000          0.940000     0.209600      13.071630
# 75%       0.000000          2.500000     0.321518      49.514000
# max       3.000000        263.000000     6.000000  320000.000000
#
#        SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# count      1406.000000   1108.000000     328.000000     43.000000
# mean          2.000170      0.166910     150.363823    144.200847
# std          19.352699      0.189760     117.859945    127.865952
# min           0.004420      0.000000    -233.000000   -174.640000
# ...

# %%
exoplanets['PlanetaryMassJpt'].describe()
# Out:
# count    1313.000000
# mean        2.890944
# std        10.204485
# min         0.000008
# 25%         0.150000
# 50%         0.940000
# 75%         2.500000
# max       263.000000
# Name: PlanetaryMassJpt, dtype: float64

# %%
pd.DataFrame.hist(exoplanets, 'DiscoveryYear', bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10dd0e3c8>]], dtype=object)

# %%
pd.DataFrame.hist(exoplanets, 'DiscoveryYear', bins=27, range=(1990,2017))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10d73beb8>]], dtype=object)

# %%
test = exoplanets['DiscoveryYear'] > 1990
#data = exoplanets[test]
#sns.distplot(data)
#sns.distplot(exoplanets['DiscoveryYear'].dropna())#,hist_kws={"range": [1990,2018]})

# %%
data = exoplanets[test]

# %%
data
# Out:
#      PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt   PeriodDays  \
# 0         HD 143761 b         0          1.045000        NaN    39.845800
# 1         HD 143761 c         0          0.079000        NaN   102.540000
# 2         KOI-1843.03         0          0.001400   0.054000     0.176891
# 5          Kepler-9 b         0          0.250000   0.840000    19.224180
# 6          Kepler-9 c         0          0.170000   0.820000    39.031060
# 7          Kepler-9 d         0          0.022000   0.147000     1.592851
# 8          GJ 160.2 b         0          0.032100        NaN     5.235400
# 9        Kepler-566 b         0               NaN   0.192000    18.427946
# 10         WASP-124 b         0          0.600000   1.240000     3.372650
# 11        HD 240210 b         0          5.210000        NaN   501.750000
# 12     OGLE-05-390L b         0          0.017000        NaN  3500.000000
# 13      Kepler-1343 b         0               NaN   0.172000     3.351832
# ...

# %%
sns.distplot(data['DiscoveryYear'])
